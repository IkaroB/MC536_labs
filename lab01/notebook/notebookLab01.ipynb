# %% [markdown]
# #Tarefa 1
#
# > PIB de todos os países entre 2010 e 2019

# %%
import pandas as pd
file = "/content/drive/My Drive/MC536/lab01/WorldGDP2010-2019.xlsx"
data = pd.read_excel(file)
print(data)
# Out:
#                                           Series Name  ... 2019 [YR2019]
# 0                                   GDP (current US$)  ...   1.91014e+10
# 1                                   GDP (current US$)  ...   1.52781e+10
# 2                                   GDP (current US$)  ...   1.69988e+11
# 3                                   GDP (current US$)  ...            ..
# 4                                   GDP (current US$)  ...   3.15406e+09
# ..                                                ...  ...           ...
# 217                                               NaN  ...           NaN
# 218                                               NaN  ...           NaN
# 219                                               NaN  ...           NaN
# 220  Data from database: World Development Indicators  ...           NaN
# 221                          Last Updated: 09/16/2020  ...           NaN
#
# [222 rows x 14 columns]

# %% [markdown]
# > Porcentagem de pessoas que sofreram violência sexual antes de completar 18 anos

# %%
import pandas as pd

df = pd.read_csv('/content/drive/My Drive/MC536/lab01/sexualViolenceUnderAge18DS.csv')

print(df)
# Out:
#       Geographic area  ...                                       OBS_FOOTNOTE
# 0         Afghanistan  ...  Ever-married girls who experienced sexual viol...
# 1              Angola  ...                                                NaN
# 2             Burundi  ...                                                NaN
# 3            Cambodia  ...                                                NaN
# 4            Cameroon  ...                                                NaN
# ..                ...  ...                                                ...
# 275  Papua New Guinea  ...                                                NaN
# 276      South Africa  ...                                                NaN
# 277             Benin  ...                                                NaN
# 278           Nigeria  ...                                                NaN
# 279  Papua New Guinea  ...                                                NaN
#
# [280 rows x 25 columns]
