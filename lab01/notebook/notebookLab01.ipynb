# %% [markdown]
# #Tarefa 1
#
# > PIB de todos os países entre 2010 e 2019

# %%
import pandas as pd
file = "../WorldGDP2010-2019.xlsx"
data = pd.read_excel(file)
print(data)

# %% [markdown]
# > Porcentagem de pessoas que sofreram violência sexual antes de completar 18 anos

# %%
import pandas as pd

df = pd.read_csv('../sexualViolenceUnderAge18DS.csv')

print(df)
